# %%
import json
import pandas as pd
from web3 import Web3
from ens import ENS
import os
from dotenv import load_dotenv
load_dotenv()
ALCHEMY_MAINNET_API_KEY = os.getenv('ALCHEMY_MAINNET_API_KEY')


with open('vuedapp-gg20-2.json') as f:
	donations = json.load(f)

df = pd.DataFrame(donations)
df
# Out:
#                                                   hash  \
# 0    0x2e089247ee9aa1545f6da98a254882e30a6801a28b3c...
# 1    0x8eb6a3e3fd9773ab0521285fbff1fa65b541fb2827a1...
# 2    0x477a42de0b89474f91b2de073ae1bdfd79af46cfc1d3...
# 3    0x94fd4fbd6d488a6dcf07bcdfb6fd3fcfb21df961c2f8...
# 4    0xe0173106099473a467b22eb2aeece57557ecb412997c...
# ..                                                 ...
# 695  0xc757eebeff0bd14c0d9fb49049794c0fd0f662bae924...
# 696  0x4f69f00ce3ef0130d880e9b7c2df7009c47835bc3b36...
# 697  0x414efe0670ed36b8026bd9633236e06d3c41247488b8...
# 698  0x59571d715146ea22c358fa5d28c0e16d079ab2986970...
# 699  0x31623d265c4a96468e8e3f52b1779d39fbb455d125d8...
#
#                                            from  \
# 0    0x8e1bD5Da87C14dd8e08F7ecc2aBf9D1d558ea174
# 1    0x1B48bB09930676d99dDA36C1aD27ff0a5A5f3911
# 2    0x8e1bD5Da87C14dd8e08F7ecc2aBf9D1d558ea174
# 3    0x8e1bD5Da87C14dd8e08F7ecc2aBf9D1d558ea174
# 4    0x1B48bB09930676d99dDA36C1aD27ff0a5A5f3911
# ...

# %%
w3 = Web3(Web3.HTTPProvider(f'https://eth-mainnet.g.alchemy.com/v2/{ALCHEMY_MAINNET_API_KEY}'))
ns = ENS.from_web3(w3)

domain = ns.name('0x96A4715280c3Dac3F3093d51aA278aA5eb60ffDE')
domain
# Out:
# 'johnson86tw.eth'

# %%
# warning: this is slow. I run 80m 2s for 700 transactions
ens_names = {}

def get_ens_name(donor):
    # If the name is already in the dictionary, return it
    if donor in ens_names:
        return ens_names[donor]

    # Otherwise, do the lookup and store the result in the dictionary
    try:
        name = ns.name(donor)
        ens_names[donor] = name
        return name
    except Exception:
        ens_names[donor] = None
        return None

df['donor_ens'] = df['donor'].apply(get_ens_name)

df
# Out:
#                                                   hash  \
# 0    0x2e089247ee9aa1545f6da98a254882e30a6801a28b3c...
# 1    0x8eb6a3e3fd9773ab0521285fbff1fa65b541fb2827a1...
# 2    0x477a42de0b89474f91b2de073ae1bdfd79af46cfc1d3...
# 3    0x94fd4fbd6d488a6dcf07bcdfb6fd3fcfb21df961c2f8...
# 4    0xe0173106099473a467b22eb2aeece57557ecb412997c...
# ..                                                 ...
# 695  0xc757eebeff0bd14c0d9fb49049794c0fd0f662bae924...
# 696  0x4f69f00ce3ef0130d880e9b7c2df7009c47835bc3b36...
# 697  0x414efe0670ed36b8026bd9633236e06d3c41247488b8...
# 698  0x59571d715146ea22c358fa5d28c0e16d079ab2986970...
# 699  0x31623d265c4a96468e8e3f52b1779d39fbb455d125d8...
#
#                                            from  \
# 0    0x8e1bD5Da87C14dd8e08F7ecc2aBf9D1d558ea174
# 1    0x1B48bB09930676d99dDA36C1aD27ff0a5A5f3911
# 2    0x8e1bD5Da87C14dd8e08F7ecc2aBf9D1d558ea174
# 3    0x8e1bD5Da87C14dd8e08F7ecc2aBf9D1d558ea174
# 4    0x1B48bB09930676d99dDA36C1aD27ff0a5A5f3911
# ...

# %%
df.to_json('vuedapp-gg20-3.json', orient="records")
